# %%
# !pip install --user networkx[default]
# Out:
# Requirement already satisfied: networkx[default] in c:\users\heill\anaconda3\lib\site-packages (3.1)
# Requirement already satisfied: pandas>=1.3; extra == "default" in c:\users\heill\anaconda3\lib\site-packages (from networkx[default]) (2.0.3)
# Requirement already satisfied: scipy>=1.8; extra == "default" in c:\users\heill\appdata\roaming\python\python38\site-packages (from networkx[default]) (1.10.1)
# Requirement already satisfied: matplotlib>=3.4; extra == "default" in c:\users\heill\appdata\roaming\python\python38\site-packages (from networkx[default]) (3.7.5)
# Requirement already satisfied: numpy>=1.20; extra == "default" in c:\users\heill\anaconda3\lib\site-packages (from networkx[default]) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\heill\anaconda3\lib\site-packages (from pandas>=1.3; extra == "default"->networkx[default]) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\heill\anaconda3\lib\site-packages (from pandas>=1.3; extra == "default"->networkx[default]) (2024.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\heill\anaconda3\lib\site-packages (from pandas>=1.3; extra == "default"->networkx[default]) (2020.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\heill\anaconda3\lib\site-packages (from matplotlib>=3.4; extra == "default"->networkx[default]) (8.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\heill\anaconda3\lib\site-packages (from matplotlib>=3.4; extra == "default"->networkx[default]) (4.57.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\heill\anaconda3\lib\site-packages (from matplotlib>=3.4; extra == "default"->networkx[default]) (2.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\heill\anaconda3\lib\site-packages (from matplotlib>=3.4; extra == "default"->networkx[default]) (1.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\heill\anaconda3\lib\site-packages (from matplotlib>=3.4; extra == "default"->networkx[default]) (24.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\heill\anaconda3\lib\site-packages (from matplotlib>=3.4; extra == "default"->networkx[default]) (1.3.0)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in c:\users\heill\anaconda3\lib\site-packages (from matplotlib>=3.4; extra == "default"->networkx[default]) (6.4.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\heill\anaconda3\lib\site-packages (from matplotlib>=3.4; extra == "default"->networkx[default]) (0.10.0)
# Requirement already satisfied: six>=1.5 in c:\users\heill\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3; extra == "default"->networkx[default]) (1.15.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in c:\users\heill\anaconda3\lib\site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib>=3.4; extra == "default"->networkx[default]) (3.4.0)

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
cip_soc = pd.read_csv("CIP_SOC.csv", encoding='cp1252')
cip_soc_matches = cip_soc[cip_soc['CIP2020Title'] != "NO MATCH"]
cip_soc_matches = cip_soc_matches.astype(str)
cip_soc_matches
# Out:
#      CIP2020Code                                   CIP2020Title SOC2018Code  \
# 0            1.0                          Agriculture, General.     19-1011
# 1            1.0                          Agriculture, General.     19-1012
# 2            1.0                          Agriculture, General.     19-1013
# 3            1.0                          Agriculture, General.     19-4012
# 4            1.0                          Agriculture, General.     25-1041
# ...          ...                                            ...         ...
# 5912     61.2899  Urology Residency/Fellowship Programs, Other.     29-1249
# 5913     61.9999  Medical Residency/Fellowship Programs, Other.     19-1042
# 5914     61.9999  Medical Residency/Fellowship Programs, Other.     25-1071
# 5915     61.9999  Medical Residency/Fellowship Programs, Other.     29-1229
# 5916     61.9999  Medical Residency/Fellowship Programs, Other.     29-1249
#
#                                        SOC2018Title
# 0                                 Animal Scientists
# 1                 Food Scientists and Technologists
# 2                         Soil and Plant Scientists
# 3                          Agricultural Technicians
# 4     Agricultural Sciences Teachers, Postsecondary
# ...                                             ...
# 5912                            Surgeons, All Other
# 5913     Medical Scientists, Except Epidemiologists
# 5914     Health Specialties Teachers, Postsecondary
# 5915                          Physicians, All Other
# 5916                            Surgeons, All Other
#
# [5917 rows x 4 columns]

# %%
cip_soc_np = cip_soc_matches.to_numpy()
match_edges = [(str(row[0]), str(row[2])) for row in cip_soc_np]
len(match_edges)
# Out:
# 5917

# %%
G = nx.Graph()
G.add_edges_from(match_edges)

# %%
#nx.draw(G) # Not helpful

# %%
from networkx.algorithms.community import greedy_modularity_communities, louvain
communities = louvain.louvain_communities(G, resolution=15) #better split than grreedy

# %%
help(louvain)
# Out:
# Help on module networkx.algorithms.community.louvain in networkx.algorithms.community:
#
# NAME
#     networkx.algorithms.community.louvain
#
# DESCRIPTION
#     Function for detecting communities based on Louvain Community Detection
#     Algorithm
#
# FUNCTIONS
#     louvain_communities(G, weight='weight', resolution=1, threshold=1e-07, seed=None)
#         Find the best partition of a graph using the Louvain Community Detection
#         Algorithm.
#
#         Louvain Community Detection Algorithm is a simple method to extract the community
#         structure of a network. This is a heuristic method based on modularity optimization. [1]_
#
#         The algorithm works in 2 steps. On the first step it assigns every node to be
#         in its own community and then for each node it tries to find the maximum positive
#         modularity gain by moving each node to all of its neighbor communities. If no positive
#         gain is achieved the node remains in its original community.
#
#         The modularity gain obtained by moving an isolated node $i$ into a community $C$ can
#         easily be calculated by the following formula (combining [1]_ [2]_ and some algebra):
#
#         .. math::
#             \Delta Q = \frac{k_{i,in}}{2m} - \gamma\frac{ \Sigma_{tot} \cdot k_i}{2m^2}
#
#         where $m$ is the size of the graph, $k_{i,in}$ is the sum of the weights of the links
#         from $i$ to nodes in $C$, $k_i$ is the sum of the weights of the links incident to node $i$,
#         $\Sigma_{tot}$ is the sum of the weights of the links incident to nodes in $C$ and $\gamma$
#         is the resolution parameter.
#
#         For the directed case the modularity gain can be computed using this formula according to [3]_
#
#         .. math::
#             \Delta Q = \frac{k_{i,in}}{m}
#             - \gamma\frac{k_i^{out} \cdot\Sigma_{tot}^{in} + k_i^{in} \cdot \Sigma_{tot}^{out}}{m^2}
#
#         where $k_i^{out}$, $k_i^{in}$ are the outer and inner weighted degrees of node $i$ and
#         $\Sigma_{tot}^{in}$, $\Sigma_{tot}^{out}$ are the sum of in-going and out-going links incident
#         to nodes in $C$.
#
#         The first phase continues until no individual move can improve the modularity.
#
#         The second phase consists in building a new network whose nodes are now the communities
#         found in the first phase. To do so, the weights of the links between the new nodes are given by
#         the sum of the weight of the links between nodes in the corresponding two communities. Once this
#         phase is complete it is possible to reapply the first phase creating bigger communities with
#         increased modularity.
#
#         The above two phases are executed until no modularity gain is achieved (or is less than
#         the `threshold`).
#
#         Parameters
#         ----------
#         G : NetworkX graph
#         weight : string or None, optional (default="weight")
#             The name of an edge attribute that holds the numerical value
#             used as a weight. If None then each edge has weight 1.
#         resolution : float, optional (default=1)
#             If resolution is less than 1, the algorithm favors larger communities.
#             Greater than 1 favors smaller communities
#         threshold : float, optional (default=0.0000001)
#             Modularity gain threshold for each level. If the gain of modularity
#             between 2 levels of the algorithm is less than the given threshold
#             then the algorithm stops and returns the resulting communities.
#         seed : integer, random_state, or None (default)
#             Indicator of random number generation state.
#             See :ref:`Randomness<randomness>`.
#
#         Returns
#         -------
#         list
#             A list of sets (partition of `G`). Each set represents one community and contains
#             all the nodes that constitute it.
#
#         Examples
#         --------
#         >>> import networkx as nx
#         >>> G = nx.petersen_graph()
#         >>> nx.community.louvain_communities(G, seed=123)
#         [{0, 4, 5, 7, 9}, {1, 2, 3, 6, 8}]
#
#         Notes
#         -----
#         The order in which the nodes are considered can affect the final output. In the algorithm
#         the ordering happens using a random shuffle.
#
#         References
#         ----------
#         .. [1] Blondel, V.D. et al. Fast unfolding of communities in
#            large networks. J. Stat. Mech 10008, 1-12(2008). https://doi.org/10.1088/1742-5468/2008/10/P10008
#         .. [2] Traag, V.A., Waltman, L. & van Eck, N.J. From Louvain to Leiden: guaranteeing
#            well-connected communities. Sci Rep 9, 5233 (2019). https://doi.org/10.1038/s41598-019-41695-z
#         .. [3] Nicolas Dugué, Anthony Perez. Directed Louvain : maximizing modularity in directed networks.
#             [Research Report] Université d’Orléans. 2015. hal-01231784. https://hal.archives-ouvertes.fr/hal-01231784
#
#         See Also
#         --------
#         louvain_partitions
#
#     louvain_partitions(G, weight='weight', resolution=1, threshold=1e-07, seed=None)
#         Yields partitions for each level of the Louvain Community Detection Algorithm
#
#         Louvain Community Detection Algorithm is a simple method to extract the community
#         structure of a network. This is a heuristic method based on modularity optimization. [1]_
#
#         The partitions at each level (step of the algorithm) form a dendogram of communities.
#         A dendrogram is a diagram representing a tree and each level represents
#         a partition of the G graph. The top level contains the smallest communities
#         and as you traverse to the bottom of the tree the communities get bigger
#         and the overall modularity increases making the partition better.
#
#         Each level is generated by executing the two phases of the Louvain Community
#         Detection Algorithm.
#
#         Parameters
#         ----------
#         G : NetworkX graph
#         weight : string or None, optional (default="weight")
#          The name of an edge attribute that holds the numerical value
#          used as a weight. If None then each edge has weight 1.
#         resolution : float, optional (default=1)
#             If resolution is less than 1, the algorithm favors larger communities.
#             Greater than 1 favors smaller communities
#         threshold : float, optional (default=0.0000001)
#          Modularity gain threshold for each level. If the gain of modularity
#          between 2 levels of the algorithm is less than the given threshold
#          then the algorithm stops and returns the resulting communities.
#         seed : integer, random_state, or None (default)
#          Indicator of random number generation state.
#          See :ref:`Randomness<randomness>`.
#
#         Yields
#         ------
#         list
#             A list of sets (partition of `G`). Each set represents one community and contains
#             all the nodes that constitute it.
#
#         References
#         ----------
#         .. [1] Blondel, V.D. et al. Fast unfolding of communities in
#            large networks. J. Stat. Mech 10008, 1-12(2008)
#
#         See Also
#         --------
#         louvain_communities
#
# DATA
#     __all__ = ['louvain_communities', 'louvain_partitions']
#
# FILE
#     c:\users\heill\anaconda3\lib\site-packages\networkx\algorithms\community\louvain.py

# %%
len(communities)
# Out:
# 190

# %%
for community in communities:
    print(len(community))
# Out:
# 11
# 37
# 16
# 13
# 16
# 18
# 195
# 4
# 36
# 26
# 4
# 18
# 3
# 4
# 22
# 17
# 24
# 25
# 15
# 6
# 55
# 65
# 10
# 6
# 30
# 25
# 19
# 14
# 23
# 7
# 20
# 8
# 20
# 16
# 11
# 2
# 16
# 3
# 15
# 11
# 2
# 22
# 27
# 23
# 24
# 9
# 22
# 5
# 14
# 9
# 30
# 12
# 62
# 24
# 15
# 14
# 10
# 30
# 2
# 23
# 10
# 34
# 2
# 10
# 12
# 2
# 39
# 11
# 9
# 6
# 31
# 11
# 5
# 9
# 25
# 11
# 6
# 19
# 15
# 21
# 36
# 10
# 3
# 6
# 17
# 20
# 16
# 2
# 45
# 17
# 13
# 27
# 12
# 36
# 2
# 23
# 39
# 7
# 6
# 2
# 2
# 2
# 6
# 2
# 2
# 2
# 2
# 3
# 26
# 2
# 2
# 12
# 2
# 4
# 3
# 3
# 6
# 9
# 2
# 2
# 6
# 35
# 10
# 42
# 2
# 7
# 22
# 3
# 3
# 4
# 2
# 2
# 2
# 2
# 9
# 18
# 2
# 2
# 2
# 2
# 6
# 3
# 2
# 23
# 2
# 23
# 2
# 2
# 2
# 2
# 6
# 10
# 8
# 10
# 18
# 9
# 19
# 45
# 19
# 4
# 25
# 12
# 2
# 2
# 4
# 34
# 11
# 2
# 2
# 12
# 9
# 3
# 13
# 34
# 19
# 5
# 79
# 17
# 2
# 15
# 15
# 26
# 29
# 3
# 15
# 15
# 8
# 5
# 16
# 18

# %%
#First make sure no single codes are left without community
import random
n = random.randint(0, len(communities)-1)
for code in communities[n]:
    name = None
    code_type ="CIP"
    if "." in code:
        aoi = cip_soc[cip_soc['CIP2020Code'].astype(str) == str(code)]['CIP2020Title'].reset_index(drop=True)
        name = aoi[0]
    elif "-" in code:
        aoi =  cip_soc[cip_soc['SOC2018Code'] == code]['SOC2018Title'].reset_index(drop=True)
        name = aoi[0]
        code_type = "SOC"
    print(code, code_type, name)
# Out:
# 9.0499 CIP Journalism, Other.
# 13-1131 SOC Fundraisers
# 9.0903 CIP Advertising.
# 9.0406 CIP Cultural Journalism.
# 9.0701 CIP Radio and Television.
# 9.0904 CIP Political Communication.
# 9.01 CIP Communication, General.
# 27-3031 SOC Public Relations Specialists
# 11-2033 SOC Fundraising Managers
# 9.0102 CIP Mass Communication/Media Studies.
# 9.09 CIP Public Relations, Advertising, and Applied Communication.
# 11-2032 SOC Public Relations Managers
# 9.0402 CIP Broadcast Journalism.
# 25-1122 SOC Communications Teachers, Postsecondary
# 9.0907 CIP International and Intercultural Communication.
# 9.0101 CIP Speech Communication and Rhetoric.
# 9.0905 CIP Health Communication.
# 27-3011 SOC Broadcast Announcers and Radio Disc Jockeys
# 52.0501 CIP Business/Corporate Communications, General.
# 9.0902 CIP Public Relations/Image Management.
# 11-2011 SOC Advertising and Promotions Managers
# 27-3023 SOC News Analysts, Reporters, and Journalists
# 9.0909 CIP Communication Management and Strategic Communications.
# 52.0502 CIP Grantsmanship.
# 9.0407 CIP Science/Health/Environmental Journalism.
# 52.0599 CIP Business/Corporate Communications, Other.
# 9.0906 CIP Sports Communication.
# 9.0405 CIP Business and Economic Journalism.

# %%
rows = []
for idx in range(len(communities)):
    cips = []
    socs = []
    for code in communities[idx]:
        name = None
        code_type ="CIP"
        if "." in code:
            aoi = cip_soc[cip_soc['CIP2020Code'].astype(str) == str(code)]['CIP2020Title'].reset_index(drop=True)
            name = aoi[0]
            cips.append({"code": code, "name": name})
        elif "-" in code:
            aoi =  cip_soc[cip_soc['SOC2018Code'] == code]['SOC2018Title'].reset_index(drop=True)
            name = aoi[0]
            code_type = "SOC"
            socs.append({"code": code, "name": name})
    rows.append({"idx":idx, "cips":cips, "socs":socs})

# %%
rows[:5]
# Out:
# [{'idx': 0,
#   'cips': [{'code': '26.0301', 'name': 'Botany/Plant Biology.'},
#    {'code': '26.0399', 'name': 'Botany/Plant Biology, Other.'},
#    {'code': '1.0', 'name': 'Agriculture, General.'},
#    {'code': '1.1199', 'name': 'Plant Sciences, Other.'},
#    {'code': '1.1104',
#     'name': 'Agricultural and Horticultural Plant Breeding.'},
#    {'code': '1.1202', 'name': 'Soil Chemistry and Physics.'},
#    {'code': '1.1299', 'name': 'Soil Sciences, Other.'},
#    {'code': '26.0308', 'name': 'Plant Molecular Biology.'},
#    {'code': '26.0307', 'name': 'Plant Physiology.'},
#    {'code': '26.0305', 'name': 'Plant Pathology/Phytopathology.'}],
#   'socs': [{'code': '19-1013', 'name': 'Soil and Plant Scientists'}]},
#  {'idx': 1,
#   'cips': [{'code': '1.1105',
#     'name': 'Plant Protection and Integrated Pest Management.'},
#    {'code': '1.0101',
#     'name': 'Agricultural Business and Management, General.'},
#    {'code': '1.0304', 'name': 'Crop Production.'},
#    {'code': '1.0308', 'name': 'Agroecology and Sustainable Agriculture.'},
#    {'code': '1.031', 'name': 'Apiculture.'},
#    {'code': '1.0303', 'name': 'Aquaculture.'},
#    {'code': '1.1101', 'name': 'Plant Sciences, General.'},
#    {'code': '1.0904', 'name': 'Animal Nutrition.'},
#    {'code': '1.1201', 'name': 'Soil Science and Agronomy, General.'},
#    {'code': '1.0905', 'name': 'Dairy Science.'},
#    {'code': '1.0102',
#     'name': 'Agribusiness/Agricultural Business Operations.'},
#    {'code': '1.0906', 'name': 'Livestock Management.'},
#    {'code': '1.0999', 'name': 'Animal Sciences, Other.'},
#    {'code': '3.0301',
#     'name': 'Fishing and Fisheries Sciences and Management.'},
#    {'code': '1.1103', 'name': 'Horticultural Science.'},
#    {'code': '1.0901', 'name': 'Animal Sciences, General.'},
#    {'code': '1.0302', 'name': 'Animal/Livestock Husbandry and Production.'},
#    {'code': '1.0902', 'name': 'Agricultural Animal Breeding.'},
#    {'code': '1.0903', 'name': 'Animal Health.'},
#    {'code': '1.0907', 'name': 'Poultry Science.'},
#    {'code': '1.0307',
#     'name': 'Horse Husbandry/Equine Science and Management.'},
#    {'code': '1.1399',
#     'name': 'Agriculture/Veterinary Preparatory Programs, Other.'},
#    {'code': '1.0199', 'name': 'Agricultural Business and Management, Other.'},
#    {'code': '1.0401', 'name': 'Agricultural and Food Products Processing.'},
#    {'code': '1.0399', 'name': 'Agricultural Production Operations, Other.'},
#    {'code': '1.0104', 'name': 'Farm/Farm and Ranch Management.'},
#    {'code': '1.0306', 'name': 'Dairy Husbandry and Production.'},
#    {'code': '1.0301', 'name': 'Agricultural Production Operations, General.'},
#    {'code': '1.1102', 'name': 'Agronomy and Crop Science.'}],
#   'socs': [{'code': '45-3031', 'name': 'Fishing and Hunting Workers'},
#    {'code': '19-4012', 'name': 'Agricultural Technicians'},
#    {'code': '11-9013',
#     'name': 'Farmers, Ranchers, and Other Agricultural Managers'},
#    {'code': '25-1041',
#     'name': 'Agricultural Sciences Teachers, Postsecondary'},
#    {'code': '45-2011', 'name': 'Agricultural Inspectors'},
#    {'code': '45-1011',
#     'name': 'First-Line Supervisors of Farming, Fishing, and Forestry Workers'},
#    {'code': '45-2093',
#     'name': 'Farmworkers, Farm, Ranch, and Aquacultural Animals'},
#    {'code': '45-2021', 'name': 'Animal Breeders'}]},
#  {'idx': 2,
#   'cips': [{'code': '52.0601', 'name': 'Business/Managerial Economics.'},
#    {'code': '30.4001', 'name': 'Economics and Foreign Language/Literature.'},
#    {'code': '3.0204', 'name': 'Environmental/Natural Resource Economics.'},
#    {'code': '45.0699', 'name': 'Economics, Other.'},
#    {'code': '45.0602', 'name': 'Applied Economics.'},
#    {'code': '30.3901', 'name': 'Economics and Computer Science.'},
#    {'code': '45.0605', 'name': 'International Economics.'},
#    {'code': '30.4901', 'name': 'Mathematical Economics.'},
#    {'code': '51.2007', 'name': 'Pharmacoeconomics/Pharmaceutical Economics.'},
#    {'code': '45.0603', 'name': 'Econometrics and Quantitative Economics.'},
#    {'code': '1.0103', 'name': 'Agricultural Economics.'},
#    {'code': '45.0601', 'name': 'Economics, General.'},
#    {'code': '45.0604',
#     'name': 'Development Economics and International Development.'}],
#   'socs': [{'code': '19-3022', 'name': 'Survey Researchers'},
#    {'code': '25-1063', 'name': 'Economics Teachers, Postsecondary'},
#    {'code': '19-3011', 'name': 'Economists'}]},
#  {'idx': 3,
#   'cips': [{'code': '47.0608',
#     'name': 'Aircraft Powerplant Technology/Technician.'},
#    {'code': '14.1901', 'name': 'Mechanical Engineering.'},
#    {'code': '47.0607',
#     'name': 'Airframe Mechanics and Aircraft Maintenance Technology/Technician.'},
#    {'code': '47.0609', 'name': 'Avionics Maintenance Technology/Technician.'},
#    {'code': '14.0202', 'name': 'Astronautical Engineering.'},
#    {'code': '14.0201',
#     'name': 'Aerospace, Aeronautical, and Astronautical/Space Engineering, General.'},
#    {'code': '14.0299',
#     'name': 'Aerospace, Aeronautical, and Astronautical/Space Engineering, Other.'}],
#   'socs': [{'code': '51-2011',
#     'name': 'Aircraft Structure, Surfaces, Rigging, and Systems Assemblers'},
#    {'code': '49-2091', 'name': 'Avionics Technicians'},
#    {'code': '17-2011', 'name': 'Aerospace Engineers'},
#    {'code': '13-1051', 'name': 'Cost Estimators'},
#    {'code': '17-2141', 'name': 'Mechanical Engineers'},
#    {'code': '49-3011', 'name': 'Aircraft Mechanics and Service Technicians'}]},
#  {'idx': 4,
#   'cips': [{'code': '47.0303',
#     'name': 'Industrial Mechanics and Maintenance Technology/Technician.'},
#    {'code': '1.0204', 'name': 'Agricultural Power Machinery Operation.'},
#    {'code': '1.0205',
#     'name': 'Agricultural Mechanics and Equipment/Machine Technology/Technician.'},
#    {'code': '1.0299', 'name': 'Agricultural Mechanization, Other.'},
#    {'code': '47.0302',
#     'name': 'Heavy Equipment Maintenance Technology/Technician.'},
#    {'code': '1.0207', 'name': 'Irrigation Management Technology/Technician.'},
#    {'code': '1.0201', 'name': 'Agricultural Mechanization, General.'}],
#   'socs': [{'code': '47-4021',
#     'name': 'Elevator and Escalator Installers and Repairers'},
#    {'code': '49-3042',
#     'name': 'Mobile Heavy Equipment Mechanics, Except Engines'},
#    {'code': '49-3041',
#     'name': 'Farm Equipment Mechanics and Service Technicians'},
#    {'code': '49-9044', 'name': 'Millwrights'},
#    {'code': '49-9043', 'name': 'Maintenance Workers, Machinery'},
#    {'code': '49-9012',
#     'name': 'Control and Valve Installers and Repairers, Except Mechanical Door'},
#    {'code': '49-3043', 'name': 'Rail Car Repairers'},
#    {'code': '49-9045',
#     'name': 'Refractory Materials Repairers, Except Brickmasons'},
#    {'code': '45-2091', 'name': 'Agricultural Equipment Operators'}]}]

# %%
df = pd.DataFrame(rows)

# %%
import json 
file_path = "uoa.json"
with open(file_path, "w") as json_file:
    json.dump(rows, json_file, indent=4)
